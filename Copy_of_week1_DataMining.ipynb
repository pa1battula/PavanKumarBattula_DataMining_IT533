# %%
import pandas as pd
url = "https://raw.githubusercontent.com/shstreuber/Data-Mining/master/data/adult.data.simplified24.csv"
df2 = pd.read_csv(url)

# %%
fill_data2 = df2[df2['nativecountry'] == "Cuba"]

# %%
fill_data2
# Out:
#        age         workclass     education  educationyears  \
# 4       28           Private     Bachelors              13
# 81      52           Private     Bachelors              13
# 638     47      Self-emp-inc       5th-6th               3
# 701     31           Private     Bachelors              13
# 1237    41  Self-emp-not-inc       HS-grad               9
# ...    ...               ...           ...             ...
# 22181   27           Private     Bachelors              13
# 22954   34           Private     Bachelors              13
# 23503   39           Private       HS-grad               9
# 23631   53           Private  Some-college              10
# 23836   54  Self-emp-not-inc       7th-8th               4
#
#             maritalstatus        occupation    relationship   race     sex  \
# 4      Married-civ-spouse    Prof-specialty            Wife  Black  Female
# 81     Married-civ-spouse     Other-service         Husband  White    Male
# 638    Married-civ-spouse  Transport-moving         Husband  White    Male
# 701               Widowed             Sales       Unmarried  White  Female
# 1237   Married-civ-spouse             Sales  Other-relative  White  Female
# ...                   ...               ...             ...    ...     ...
# 22181  Married-civ-spouse      Adm-clerical            Wife  White  Female
# 22954       Never-married    Prof-specialty   Not-in-family  White  Female
# 23503  Married-civ-spouse  Transport-moving         Husband  Black    Male
# 23631           Separated      Adm-clerical       Own-child  White    Male
# 23836            Divorced  Transport-moving   Not-in-family  White    Male
#
#        hoursperweek nativecountry  incomeUSD
# 4                40          Cuba      23429
# 81               40          Cuba      38723
# 638              50          Cuba      38773
# 701              40          Cuba      32584
# 1237             40          Cuba      23246
# ...             ...           ...        ...
# 22181            40          Cuba      60611
# 22954            45          Cuba      23933
# 23503            40          Cuba      31304
# 23631            40          Cuba      27039
# 23836            45          Cuba      49135
#
# [72 rows x 12 columns]

# %%
from google.colab import files
fill_data2.to_csv('./fill_data2.csv', sep = ',')
files.download('fill_data2.csv')
